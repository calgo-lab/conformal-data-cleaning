# %%
from conformal_data_cleaning.demo_interface import fit_and_get_cleaner
from conformal_data_cleaning.cleaner import ConformalForestCleaner
from conformal_data_cleaning.data import _fetch_and_save_datasets
import pandas as pd
from sklearn.model_selection import train_test_split
from tab_err.api import high_level
from pathlib import Path

_fetch_and_save_datasets(Path("."))

df = pd.read_csv("44969.csv")

train_df, test_df = train_test_split(
    df,
    test_size = 0.2,
    random_state=1
)

test_df, _ = high_level.create_errors(test_df, 0.1)

fit_cleaner = fit_and_get_cleaner(cleaner=ConformalForestCleaner.__name__, train_df=train_df, confidence_level=0.9, seed=1)
cleaned_test_df, cleaned_mask = fit_cleaner.transform(test_df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from conformal_data_cleaning.demo_interface import fit_and_get_cleaner
#       2 from conformal_data_cleaning.cleaner import ConformalForestCleaner
#       3 from conformal_data_cleaning.data import _fetch_and_save_datasets
#
# File ~/BHT/Research/conformal-data-cleaning/src/conformal_data_cleaning/__init__.py:7
#       4 from logging import Formatter, StreamHandler, getLogger
#       6 import numpy as np
# ----> 7 from . import cleaner
#       8 from . import conformal_inference
#      10 __all__ = ["cleaner", "conformal_inference"]
#
# File ~/BHT/Research/conformal-data-cleaning/src/conformal_data_cleaning/cleaner/__init__.py:3
#       1 from .conformal_forest import ConformalForestCleaner
#       2 from .forest import ForestCleaner
# ----> 3 from .precision_forest import PrecisionForestCleaner
#       5 __all__ = ["ConformalForestCleaner", "ForestCleaner", "PrecisionForestCleaner"]
#
# File ~/BHT/Research/conformal-data-cleaning/src/conformal_data_cleaning/cleaner/precision_forest.py:16
#      13 from sklearn.preprocessing import OneHotEncoder, StandardScaler
#      15 from ._base import BaseCleaner
# ---> 16 from config import N_JOBS
#      18 logger = getLogger(__name__)
#      21 class PrecisionForestCleaner(BaseCleaner):
#
# ModuleNotFoundError: No module named 'config'
